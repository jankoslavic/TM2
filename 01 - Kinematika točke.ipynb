# %% [markdown]
# # Kinematika točke
# Prof. dr. Janko Slavič, Univerza v Ljubljani, Fakulteta za strojništvo

# %%
import matplotlib.pyplot as plt
import sympy as sym
sym.init_printing()

# %% [markdown]
# Če uporabite Google Colab, potem odkomentirajte (odstranite #) spodnje vrstice in jih sprožite:

# %%
#def custom_latex_printer(exp,**options):
#    from google.colab.output._publish import javascript
#    url = "https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.3/latest.js?config=default"
#    javascript(url=url)
#    return sym.printing.latex(exp,**options)
#sym.init_printing(use_latex="mathjax",latex_printer=custom_latex_printer)

# %% [markdown]
# ## Zgled časovno definirane lege

# %%
t = sym.symbols('t')

# %% [markdown]
# Definicija lege:

# %%
s = 2 + 3*t - 0.5*(t-0.5)**3
s
# Out:
#                    3
# 3⋅t - 0.5⋅(t - 0.5)  + 2

# %%
sym.plot(s, (t,0,3));

# %% [markdown]
# Hitrost:

# %%
v = s.diff(t)
v
# Out:
#                  2
# 3 - 1.5⋅(t - 0.5)

# %%
sym.plot(v, (t,0,3));

# %% [markdown]
# Pospešek:

# %%
a = s.diff(t,2) # ali: v.diff(t)
a
# Out:
# 1.5 - 3.0⋅t

# %%
sym.plot(a, (t,0,3));
